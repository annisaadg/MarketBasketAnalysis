# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth
import time

# %%
data = pd.read_csv("../datasets/ind.csv", sep = ";")
# Out:
# C:\Users\Budi\AppData\Local\Temp\ipykernel_18044\2080664985.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../datasets/ind.csv", sep = ";")

# %%
data1 = data[["BillNo", "Itemname", "Quantity"]].copy()

# %%
data1.head()
# Out:
#    BillNo                             Itemname  Quantity
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365                  WHITE METAL LANTERN         6
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6

# %%
#mengubah dari 0,0 menjadi 0
def one_hot_encoding(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
data1["Quantity"] = data1["Quantity"].apply(one_hot_encoding)

# %%
data1.head(100)
# Out:
#     BillNo                             Itemname  Quantity
# 0   536365   WHITE HANGING HEART T-LIGHT HOLDER         1
# 1   536365                  WHITE METAL LANTERN         1
# 2   536365       CREAM CUPID HEARTS COAT HANGER         1
# 3   536365  KNITTED UNION FLAG HOT WATER BOTTLE         1
# 4   536365       RED WOOLLY HOTTIE WHITE HEART.         1
# ..     ...                                  ...       ...
# 95  536378     LUNCH BOX WITH CUTLERY RETROSPOT         1
# 96  536378      PACK OF 72 RETROSPOT CAKE CASES         1
# 97  536378       PACK OF 60 DINOSAUR CAKE CASES         1
# 98  536378   PACK OF 60 PINK PAISLEY CAKE CASES         1
# 99  536378          60 TEATIME FAIRY CAKE CASES         1
#
# [100 rows x 3 columns]

# %%
data1.to_csv("../datasets/datasets2Encode.csv", index=False)

# %%
item_count_pivot = data1.pivot_table(index='BillNo' , columns='Itemname', values='Quantity').fillna(0)

# %%
item_count_pivot.head()
# Out:
# Itemname  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# BillNo
# 536365                      0.0                      0.0
# 536366                      0.0                      0.0
# 536367                      0.0                      0.0
# 536368                      0.0                      0.0
# 536369                      0.0                      0.0
#
# Itemname  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# BillNo
# 536365                       0.0                         0.0
# 536366                       0.0                         0.0
# 536367                       0.0                         0.0
# 536368                       0.0                         0.0
# 536369                       0.0                         0.0
#
# Itemname  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# BillNo
# 536365                          0.0                        0.0
# 536366                          0.0                        0.0
# ...

# %%
# Out:
# Itemname  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# BillNo
# 536365                        0                        0
# 536366                        0                        0
# 536367                        0                        0
# 536368                        0                        0
# 536369                        0                        0
# ...                         ...                      ...
# 572057                        0                        0
# 572058                        0                        0
# A563185                       0                        0
# A563186                       0                        0
# A563187                       0                        0
#
# Itemname  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# BillNo
# 536365                         0                           0
# 536366                         0                           0
# 536367                         0                           0
# ...

# %%
toss = basket[]
